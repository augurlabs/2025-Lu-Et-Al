# %% [markdown]
# # Load needed libraries

# %%
import numpy as np
import pandas as pd

# %%
U2_New_Combine_Data = pd.read_csv('U2NewCombinedFeatureswithInterFactors.csv')
U2_New_Combine_Data
# Out:
#      FirstLayer_task_speed_factor_1  FirstLayer_task_share_factor_1  \
# 0                               228                             304
# 1                                91                             252
# 2                               130                             172
# 3                               193                             201
# 4                               288                             293
# ..                              ...                             ...
# 316                              71                              26
# 317                             299                              97
# 318                             139                             154
# 319                             199                             309
# 320                             275                             218
#
#      FirstLayer_task_speed_factor_2  playerName  U2PostScoreLevel  \
# 0                                59           0                 0
# ...

# %%
U2_Task_Speed_transformed = U2_New_Combine_Data[['FirstLayer_task_speed_factor_1','FirstLayer_task_speed_factor_2','playerName','U2PostScoreLevel']]
U2_Task_Speed_transformed
# Out:
#      FirstLayer_task_speed_factor_1  FirstLayer_task_speed_factor_2  \
# 0                               228                              59
# 1                                91                              42
# 2                               130                               4
# 3                               193                              73
# 4                               288                             163
# ..                              ...                             ...
# 316                              71                              53
# 317                             299                             131
# 318                             139                             297
# 319                             199                             181
# 320                             275                             182
#
#      playerName  U2PostScoreLevel
# 0             0                 0
# 1             1                 1
# 2             2                 0
# ...

# %%
U2_Task_Speed_transformed.to_csv('FirstLayerLattentVariables/U2_Task_Speed_transformed.csv', index = False)

# %%
U2_Task_Share_transformed = U2_New_Combine_Data[['FirstLayer_task_share_factor_1','playerName','U2PostScoreLevel']]
U2_Task_Share_transformed
# Out:
#      FirstLayer_task_share_factor_1  playerName  U2PostScoreLevel
# 0                               304           0                 0
# 1                               252           1                 1
# 2                               172           2                 0
# 3                               201           2                 0
# 4                               293           3                 0
# ..                              ...         ...               ...
# 316                              26         243                 1
# 317                              97         244                 0
# 318                             154         245                 0
# 319                             309         246                 0
# 320                             218         289                 1
#
# [321 rows x 3 columns]

# %%
U2_Task_Share_transformed.to_csv('FirstLayerLattentVariables/U2_Task_Share_transformed.csv', index = False)

# %%
U2_Arg_freq_transformed = U2_New_Combine_Data[['FirstLayer_arg_freq_factor_1','FirstLayer_arg_freq_factor_2','FirstLayer_arg_freq_factor_3','FirstLayer_arg_freq_factor_4','playerName','U2PostScoreLevel']]
U2_Arg_freq_transformed
# Out:
#      FirstLayer_arg_freq_factor_1  FirstLayer_arg_freq_factor_2  \
# 0                             161                           100
# 1                              80                           290
# 2                             287                            31
# 3                              27                            53
# 4                              43                           145
# ..                            ...                           ...
# 316                            77                           257
# 317                           256                           306
# 318                            64                           307
# 319                           260                            36
# 320                           172                           283
#
#      FirstLayer_arg_freq_factor_3  FirstLayer_arg_freq_factor_4  playerName  \
# 0                              43                           269           0
# ...

# %%
U2_Arg_freq_transformed.to_csv('FirstLayerLattentVariables/U2_Arg_Freq_transformed.csv', index = False)

# %%
U2_Arg_speed_transformed = U2_New_Combine_Data[['FirstLayer_arg_speed_factor_1','FirstLayer_arg_speed_factor_2','FirstLayer_arg_speed_factor_3','FirstLayer_arg_speed_factor_4','FirstLayer_arg_speed_factor_5','playerName','U2PostScoreLevel']]
U2_Arg_speed_transformed
# Out:
#      FirstLayer_arg_speed_factor_1  FirstLayer_arg_speed_factor_2  \
# 0                              106                            150
# 1                              198                             79
# 2                              248                             61
# 3                               66                            169
# 4                              127                            149
# ..                             ...                            ...
# 316                            226                             54
# 317                            302                              1
# 318                            176                             30
# 319                            103                            144
# 320                            293                             45
#
#      FirstLayer_arg_speed_factor_3  FirstLayer_arg_speed_factor_4  \
# 0                               44                            287
# ...

# %%
U2_Arg_speed_transformed.to_csv('FirstLayerLattentVariables/U2_Arg_speed_transformed.csv', index = False)

# %%
U2_Arg_share_transformed = U2_New_Combine_Data[['FirstLayer_arg_share_factor_1','FirstLayer_arg_share_factor_2','FirstLayer_arg_share_factor_3','FirstLayer_arg_share_factor_4','playerName','U2PostScoreLevel']]
U2_Arg_share_transformed
# Out:
#      FirstLayer_arg_share_factor_1  FirstLayer_arg_share_factor_2  \
# 0                               11                            270
# 1                               46                            145
# 2                              221                            149
# 3                               78                            286
# 4                              120                            281
# ..                             ...                            ...
# 316                            151                            241
# 317                            285                            244
# 318                            185                            104
# 319                             81                            259
# 320                            102                            255
#
#      FirstLayer_arg_share_factor_3  FirstLayer_arg_share_factor_4  playerName  \
# 0                               91                             61           0
# ...

# %%
U2_Arg_share_transformed.to_csv('FirstLayerLattentVariables/U2_Arg_share_transformed.csv', index = False)

# %%
U2_hotkey_freq_transformed = U2_New_Combine_Data[['FirstLayer_hotkey_freq_factor_1','FirstLayer_hotkey_freq_factor_2','FirstLayer_hotkey_freq_factor_3','FirstLayer_hotkey_freq_factor_4','FirstLayer_hotkey_freq_factor_5','playerName','U2PostScoreLevel']]
U2_hotkey_freq_transformed
# Out:
#      FirstLayer_hotkey_freq_factor_1  FirstLayer_hotkey_freq_factor_2  \
# 0                                 19                              139
# 1                                265                               30
# 2                                 73                              147
# 3                                 23                              199
# 4                                163                               89
# ..                               ...                              ...
# 316                              102                              107
# 317                               93                              218
# 318                               25                              183
# 319                              161                              281
# 320                               71                               11
#
#      FirstLayer_hotkey_freq_factor_3  FirstLayer_hotkey_freq_factor_4  \
# ...

# %%
U2_hotkey_freq_transformed.to_csv('FirstLayerLattentVariables/U2_hotkey_freq_transformed.csv', index = False)

# %%
U2_hotkey_share_transformed = U2_New_Combine_Data[['FirstLayer_hotkey_share_factor_1','FirstLayer_hotkey_share_factor_2','FirstLayer_hotkey_share_factor_3','playerName','U2PostScoreLevel']]
U2_hotkey_share_transformed
# Out:
#      FirstLayer_hotkey_share_factor_1  FirstLayer_hotkey_share_factor_2  \
# 0                                 173                               104
# 1                                  25                               258
# 2                                  90                                91
# 3                                 189                               181
# 4                                  69                                44
# ..                                ...                               ...
# 316                               104                                47
# 317                               278                                 9
# 318                               158                                99
# 319                               153                               245
# 320                               127                               190
#
#      FirstLayer_hotkey_share_factor_3  playerName  U2PostScoreLevel
# ...

# %%
U2_hotkey_share_transformed.to_csv('FirstLayerLattentVariables/U2_hotkey_share_transformed.csv', index = False)

# %%
U2_dialogue_freq_transformed = U2_New_Combine_Data[['FirstLayer_dialogue_freq_factor_1','FirstLayer_dialogue_freq_factor_2','FirstLayer_dialogue_freq_factor_3',
                                                    'FirstLayer_dialogue_freq_factor_4','FirstLayer_dialogue_freq_factor_5','playerName','U2PostScoreLevel']]
U2_dialogue_freq_transformed
# Out:
#      FirstLayer_dialogue_freq_factor_1  FirstLayer_dialogue_freq_factor_2  \
# 0                                  139                                 86
# 1                                   25                                262
# 2                                  222                                 80
# 3                                   97                                138
# 4                                   97                                138
# ..                                 ...                                ...
# 316                                158                                 68
# 317                                104                                 75
# 318                                 54                                258
# 319                                231                                127
# 320                                 53                                120
#
#      FirstLayer_dialogue_freq_factor_3  FirstLayer_dialogue_freq_factor_4  \
# ...

# %%
U2_dialogue_freq_transformed.to_csv('FirstLayerLattentVariables/U2_dialogue_freq_transformed.csv', index = False)

# %%
U2_dialogue_speed_transformed = U2_New_Combine_Data[['FirstLayer_dialogue_speed_factor_1','FirstLayer_dialogue_speed_factor_2','FirstLayer_dialogue_speed_factor_3',
                                                    'FirstLayer_dialogue_speed_factor_4','FirstLayer_dialogue_speed_factor_5','FirstLayer_dialogue_speed_factor_6',
                                                     'FirstLayer_dialogue_speed_factor_7','playerName','U2PostScoreLevel']]
U2_dialogue_speed_transformed
# Out:
#      FirstLayer_dialogue_speed_factor_1  FirstLayer_dialogue_speed_factor_2  \
# 0                                   210                                  32
# 1                                   266                                  10
# 2                                    18                                 231
# 3                                    38                                 168
# 4                                    38                                 168
# ..                                  ...                                 ...
# 316                                 203                                  91
# 317                                 177                                  73
# 318                                 112                                 186
# 319                                  77                                  77
# 320                                  19                                 230
#
# ...

# %%
U2_dialogue_speed_transformed.to_csv('FirstLayerLattentVariables/U2_dialogue_speed_transformed.csv', index = False)

# %%
U2_dialogue_share_transformed = U2_New_Combine_Data[['FirstLayer_dialogue_share_factor_1','FirstLayer_dialogue_share_factor_2','FirstLayer_dialogue_share_factor_3',
                                                    'FirstLayer_dialogue_share_factor_4','playerName','U2PostScoreLevel']]
U2_dialogue_share_transformed
# Out:
#      FirstLayer_dialogue_share_factor_1  FirstLayer_dialogue_share_factor_2  \
# 0                                    17                                 283
# 1                                    19                                 129
# 2                                    32                                 224
# 3                                     8                                 292
# 4                                    85                                 231
# ..                                  ...                                 ...
# 316                                  27                                 218
# 317                                 151                                 143
# 318                                  73                                 229
# 319                                 270                                 121
# 320                                 107                                 199
#
# ...

# %%
U2_dialogue_share_transformed.to_csv('FirstLayerLattentVariables/U2_dialogue_share_transformed.csv', index = False)

# %%
U2_behaviorType_freq_transformed = U2_New_Combine_Data[['FirstLayer_behaviorType_freq_factor_1','playerName','U2PostScoreLevel']]
U2_behaviorType_freq_transformed
# Out:
#      FirstLayer_behaviorType_freq_factor_1  playerName  U2PostScoreLevel
# 0                                       29           0                 0
# 1                                      269           1                 1
# 2                                      277           2                 0
# 3                                      219           2                 0
# 4                                       96           3                 0
# ..                                     ...         ...               ...
# 316                                    312         243                 1
# 317                                    287         244                 0
# 318                                    308         245                 0
# 319                                    200         246                 0
# 320                                    286         289                 1
#
# [321 rows x 3 columns]

# %%
U2_behaviorType_freq_transformed.to_csv('FirstLayerLattentVariables/U2_behaviorType_freq_transformed.csv', index = False)

# %%
U2_behaviorType_speed_transformed = U2_New_Combine_Data[['FirstLayer_behaviorType_speed_factor_1','playerName','U2PostScoreLevel']]
U2_behaviorType_speed_transformed
# Out:
#      FirstLayer_behaviorType_speed_factor_1  playerName  U2PostScoreLevel
# 0                                       120           0                 0
# 1                                       191           1                 1
# 2                                        96           2                 0
# 3                                       145           2                 0
# 4                                       277           3                 0
# ..                                      ...         ...               ...
# 316                                      79         243                 1
# 317                                      22         244                 0
# 318                                      65         245                 0
# 319                                      20         246                 0
# 320                                      44         289                 1
#
# [321 rows x 3 columns]

# %%
U2_behaviorType_speed_transformed.to_csv('FirstLayerLattentVariables/U2_behaviorType_speed_transformed.csv', index = False)

# %%
U2_behaviorType_share_transformed = U2_New_Combine_Data[['FirstLayer_behaviorType_share_factor_1','playerName','U2PostScoreLevel']]
U2_behaviorType_share_transformed
# Out:
#      FirstLayer_behaviorType_share_factor_1  playerName  U2PostScoreLevel
# 0                                       269           0                 0
# 1                                       116           1                 1
# 2                                        76           2                 0
# 3                                       251           2                 0
# 4                                        84           3                 0
# ..                                      ...         ...               ...
# 316                                     129         243                 1
# 317                                      91         244                 0
# 318                                     114         245                 0
# 319                                     108         246                 0
# 320                                      32         289                 1
#
# [321 rows x 3 columns]

# %%
U2_behaviorType_share_transformed.to_csv('FirstLayerLattentVariables/U2_behaviorType_share_transformed.csv', index = False)

# %%
U2_tool_freq_transformed = U2_New_Combine_Data[['FirstLayer_tool_freq_factor_1','FirstLayer_tool_freq_factor_2','playerName','U2PostScoreLevel']]
U2_tool_freq_transformed
# Out:
#      FirstLayer_tool_freq_factor_1  FirstLayer_tool_freq_factor_2  playerName  \
# 0                              243                             40           0
# 1                               28                            315           1
# 2                              318                            305           2
# 3                              276                            171           2
# 4                              177                            270           3
# ..                             ...                            ...         ...
# 316                            105                            111         243
# 317                            197                             97         244
# 318                            236                             82         245
# 319                            166                             13         246
# 320                            167                             74         289
#
#      U2PostScoreLevel
# ...

# %%
U2_tool_freq_transformed.to_csv('FirstLayerLattentVariables/U2_tool_freq_transformed.csv', index = False)

# %%
U2_tool_speed_transformed = U2_New_Combine_Data[['FirstLayer_tool_speed_factor_1','FirstLayer_tool_speed_factor_2','playerName','U2PostScoreLevel']]
U2_tool_speed_transformed
# Out:
#      FirstLayer_tool_speed_factor_1  FirstLayer_tool_speed_factor_2  \
# 0                               203                               9
# 1                               181                              94
# 2                                13                             192
# 3                               109                             178
# 4                               254                             228
# ..                              ...                             ...
# 316                             139                              38
# 317                             270                             256
# 318                             180                             141
# 319                             172                             101
# 320                             306                              12
#
#      playerName  U2PostScoreLevel
# 0             0                 0
# 1             1                 1
# 2             2                 0
# ...

# %%
U2_tool_speed_transformed.to_csv('FirstLayerLattentVariables/U2_tool_speed_transformed.csv', index = False)

# %%
U2_tool_share_transformed = U2_New_Combine_Data[['FirstLayer_tool_share_factor_1','FirstLayer_tool_share_factor_2','playerName','U2PostScoreLevel']]
U2_tool_share_transformed
# Out:
#      FirstLayer_tool_share_factor_1  FirstLayer_tool_share_factor_2  \
# 0                               311                              11
# 1                               184                             158
# 2                               300                             162
# 3                                30                             258
# 4                               126                             233
# ..                              ...                             ...
# 316                              65                             218
# 317                             101                             122
# 318                             113                             193
# 319                             269                              76
# 320                             131                             236
#
#      playerName  U2PostScoreLevel
# 0             0                 0
# 1             1                 1
# 2             2                 0
# ...

# %%
U2_tool_share_transformed.to_csv('FirstLayerLattentVariables/U2_tool_share_transformed.csv', index = False)

# %%
U2_itemInter_freq_transformed = U2_New_Combine_Data[['FirstLayer_itemInter_freq_factor_1','playerName','U2PostScoreLevel']]
U2_itemInter_freq_transformed
# Out:
#      FirstLayer_itemInter_freq_factor_1  playerName  U2PostScoreLevel
# 0                                   191           0                 0
# 1                                   277           1                 1
# 2                                   272           2                 0
# 3                                   187           2                 0
# 4                                    88           3                 0
# ..                                  ...         ...               ...
# 316                                  96         243                 1
# 317                                  22         244                 0
# 318                                  46         245                 0
# 319                                 176         246                 0
# 320                                 178         289                 1
#
# [321 rows x 3 columns]

# %%
U2_itemInter_freq_transformed.to_csv('FirstLayerLattentVariables/U2_itemInter_freq_transformed.csv', index = False)

# %%
U2_itemInter_share_transformed = U2_New_Combine_Data[['FirstLayer_itemInter_share_factor_1','playerName','U2PostScoreLevel']]
U2_itemInter_share_transformed
# Out:
#      FirstLayer_itemInter_share_factor_1  playerName  U2PostScoreLevel
# 0                                    238           0                 0
# 1                                    304           1                 1
# 2                                    265           2                 0
# 3                                     23           2                 0
# 4                                    116           3                 0
# ..                                   ...         ...               ...
# 316                                  215         243                 1
# 317                                  200         244                 0
# 318                                  107         245                 0
# 319                                  170         246                 0
# 320                                   44         289                 1
#
# [321 rows x 3 columns]

# %%
U2_itemInter_share_transformed.to_csv('FirstLayerLattentVariables/U2_itemInter_share_transformed.csv', index = False)

# %%
U2_itemInter_Inter_transformed = U2_New_Combine_Data[['SecondLayer_item_inter_factor_1','SecondLayer_item_Inter_factor_2',
                                                      'SecondLayer_item_Inter_factor_3','SecondLayer_item_Inter_factor_4',
                                                      'playerName','U2PostScoreLevel']]
U2_itemInter_Inter_transformed
# Out:
#      SecondLayer_item_inter_factor_1  SecondLayer_item_Inter_factor_2  \
# 0                                  0                               32
# 1                                  1                              287
# 2                                  1                               46
# 3                                  1                              115
# 4                                  0                              141
# ..                               ...                              ...
# 316                                1                               75
# 317                                1                              114
# 318                                1                              272
# 319                                0                               64
# 320                                1                               97
#
#      SecondLayer_item_Inter_factor_3  SecondLayer_item_Inter_factor_4  \
# ...

# %%
U2_itemInter_Inter_transformed.to_csv('SecondLayerLattentVariables/U2_itemInter_Inter_transformed.csv', index = False)

# %%
U2_arg_Inter_transformed = U2_New_Combine_Data[['SecondLayer_arg_Inter_factor_1','SecondLayer_arg_Inter_factor_2','playerName','U2PostScoreLevel']]
U2_arg_Inter_transformed
# Out:
#      SecondLayer_arg_Inter_factor_1  SecondLayer_arg_Inter_factor_2  \
# 0                                 1                             142
# 1                                 1                             198
# 2                                 0                              40
# 3                                 0                              41
# 4                                 0                               4
# ..                              ...                             ...
# 316                               1                             153
# 317                               1                              80
# 318                               1                             199
# 319                               1                              91
# 320                               1                             141
#
#      playerName  U2PostScoreLevel
# 0             0                 0
# 1             1                 1
# 2             2                 0
# ...

# %%
U2_arg_Inter_transformed.to_csv('SecondLayerLattentVariables/U2_arg_Inter_transformed.csv', index = False)

# %%
U2_task_Inter_transformed = U2_New_Combine_Data[['SecondLayer_task_Inter_factor_1','playerName','U2PostScoreLevel']]
U2_task_Inter_transformed
# Out:
#      SecondLayer_task_Inter_factor_1  playerName  U2PostScoreLevel
# 0                                176           0                 0
# 1                                309           1                 1
# 2                                 43           2                 0
# 3                                 38           2                 0
# 4                                 41           3                 0
# ..                               ...         ...               ...
# 316                              258         243                 1
# 317                              188         244                 0
# 318                               39         245                 0
# 319                               33         246                 0
# 320                              111         289                 1
#
# [321 rows x 3 columns]

# %%
U2_task_Inter_transformed.to_csv('SecondLayerLattentVariables/U2_task_Inter_transformed.csv', index = False)

# %%
U2_hotkey_Inter_transformed = U2_New_Combine_Data[['SecondLayer_hotkey_Inter_factor_1','playerName','U2PostScoreLevel']]
U2_hotkey_Inter_transformed
# Out:
#      SecondLayer_hotkey_Inter_factor_1  playerName  U2PostScoreLevel
# 0                                  275           0                 0
# 1                                  204           1                 1
# 2                                  184           2                 0
# 3                                  225           2                 0
# 4                                  176           3                 0
# ..                                 ...         ...               ...
# 316                                111         243                 1
# 317                                 16         244                 0
# 318                                132         245                 0
# 319                                125         246                 0
# 320                                195         289                 1
#
# [321 rows x 3 columns]

# %%
U2_hotkey_Inter_transformed.to_csv('SecondLayerLattentVariables/U2_hotkey_Inter_transformed.csv', index = False)

# %%
U2_tool_Inter_transformed = U2_New_Combine_Data[['SecondLayer_tool_Inter_factor_1','playerName','U2PostScoreLevel']]
U2_tool_Inter_transformed
# Out:
#      SecondLayer_tool_Inter_factor_1  playerName  U2PostScoreLevel
# 0                                245           0                 0
# 1                                 16           1                 1
# 2                                314           2                 0
# 3                                233           2                 0
# 4                                213           3                 0
# ..                               ...         ...               ...
# 316                               85         243                 1
# 317                              180         244                 0
# 318                               43         245                 0
# 319                              306         246                 0
# 320                               31         289                 1
#
# [321 rows x 3 columns]

# %%
U2_tool_Inter_transformed.to_csv('SecondLayerLattentVariables/U2_tool_Inter_transformed.csv', index = False)

# %%
U2_dialogue_Inter_transformed = U2_New_Combine_Data[['SecondLayer_dialogue_Inter_factor_1','SecondLayer_dialogue_Inter_factor_2',
                                                     'SecondLayer_dialogue_Inter_factor_3','playerName','U2PostScoreLevel']]
U2_dialogue_Inter_transformed
# Out:
#      SecondLayer_dialogue_Inter_factor_1  SecondLayer_dialogue_Inter_factor_2  \
# 0                                    292                                  262
# 1                                     67                                   31
# 2                                    291                                  188
# 3                                    206                                  265
# 4                                    239                                  211
# ..                                   ...                                  ...
# 316                                   77                                  119
# 317                                    9                                    4
# 318                                  178                                  212
# 319                                  278                                  169
# 320                                  272                                  235
#
# ...

# %%
U2_dialogue_Inter_transformed.to_csv('SecondLayerLattentVariables/U2_dialogue_Inter_transformed.csv', index = False)

# %%
U2_map_share_size_transformed = U2_New_Combine_Data[['FirstLayer_map_share_size_factor_1','FirstLayer_map_share_size_factor_2',
                                                     'playerName','U2PostScoreLevel']]
U2_map_share_size_transformed
# Out:
#      FirstLayer_map_share_size_factor_1  FirstLayer_map_share_size_factor_2  \
# 0                                     0                                   0
# 1                                     0                                   0
# 2                                     1                                   1
# 3                                     1                                   1
# 4                                     1                                   1
# ..                                  ...                                 ...
# 316                                   1                                   1
# 317                                   1                                   1
# 318                                   1                                   1
# 319                                   1                                   1
# 320                                   1                                   0
#
#      playerName  U2PostScoreLevel
# ...

# %%
U2_map_share_size_transformed.to_csv('FirstLayerLattentVariables/U2_map_share_size_transformed.csv', index = False)

# %%
U2_thirdLayer_inter_transformed = U2_New_Combine_Data[['ThirdLayer_Inter_factor_1','ThirdLayer_Inter_factor_2','ThirdLayer_Inter_factor_3',
                                                       'ThirdLayer_Inter_factor_4','ThirdLayer_Inter_factor_5','ThirdLayer_Inter_factor_6',
                                                       'ThirdLayer_Inter_factor_7',
                                                     'playerName','U2PostScoreLevel']]
U2_thirdLayer_inter_transformed
# Out:
#      ThirdLayer_Inter_factor_1  ThirdLayer_Inter_factor_2  \
# 0                          159                        160
# 1                           20                         17
# 2                          171                        224
# 3                          233                        126
# 4                          114                        214
# ..                         ...                        ...
# 316                        119                        100
# 317                        261                        165
# 318                        193                         43
# 319                        315                        139
# 320                         62                        174
#
#      ThirdLayer_Inter_factor_3  ThirdLayer_Inter_factor_4  \
# 0                          123                        315
# 1                          287                        283
# 2                          272                        191
# ...

# %%
U2_thirdLayer_inter_transformed.to_csv('ThirdLayerLatentFeatures/U2_thirdLayer_Inter_transformed.csv', index = False)

# %%
U2_first_second_layer_transformed_features = U2_New_Combine_Data.drop(['ThirdLayer_Inter_factor_1','ThirdLayer_Inter_factor_2','ThirdLayer_Inter_factor_3',
                                                                      'ThirdLayer_Inter_factor_4','ThirdLayer_Inter_factor_5','ThirdLayer_Inter_factor_6',
                                                                      'ThirdLayer_Inter_factor_7', 'CREIScore', 'findTeamAveScore', 'PREU2', 'JasperCritiqueScore',
                                                                                'biggerArgScore','CREIScore'],axis=1)

# %%
list(U2_first_second_layer_transformed_features.columns)
# Out:
# ['FirstLayer_task_speed_factor_1',
#  'FirstLayer_task_share_factor_1',
#  'FirstLayer_task_speed_factor_2',
#  'playerName',
#  'U2PostScoreLevel',
#  'FirstLayer_arg_freq_factor_1',
#  'FirstLayer_arg_freq_factor_2',
#  'FirstLayer_arg_freq_factor_3',
#  'FirstLayer_arg_freq_factor_4',
#  'FirstLayer_arg_speed_factor_1',
#  'FirstLayer_arg_speed_factor_2',
#  'FirstLayer_arg_speed_factor_3',
#  'FirstLayer_arg_speed_factor_4',
#  'FirstLayer_arg_speed_factor_5',
#  'FirstLayer_arg_share_factor_1',
#  'FirstLayer_arg_share_factor_2',
#  'FirstLayer_arg_share_factor_3',
#  'FirstLayer_arg_share_factor_4',
#  'FirstLayer_hotkey_freq_factor_1',
#  'FirstLayer_hotkey_freq_factor_2',
#  'FirstLayer_hotkey_freq_factor_3',
#  'FirstLayer_hotkey_freq_factor_4',
#  'FirstLayer_hotkey_freq_factor_5',
#  'FirstLayer_hotkey_share_factor_1',
#  'FirstLayer_hotkey_share_factor_2',
#  'FirstLayer_hotkey_share_factor_3',
#  'FirstLayer_dialogue_freq_factor_1',
# ...

# %%
U2_first_second_layer_transformed_features.to_csv("FirstSecondLayerLatentFeatures/U2_first_second_layer_latent_features.csv",index=False)
