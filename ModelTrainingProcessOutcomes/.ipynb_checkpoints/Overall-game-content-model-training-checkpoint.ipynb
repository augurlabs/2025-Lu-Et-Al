# %% [markdown]
# # Load needed libraries

# %%
###Loading needed packages
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")
import numpy as np
from sklearn.metrics import accuracy_score, f1_score
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import KernelPCA
import operator
from numpy.linalg import *
from numpy import *
from sklearn.manifold import TSNE

# %%
### Another version of dimensional reduction
## Load the libraries
from sklearn.decomposition import (PCA, IncrementalPCA,
                                   KernelPCA, TruncatedSVD,
                                   FastICA, MiniBatchDictionaryLearning,
                                   SparsePCA)
from sklearn.manifold import (Isomap,
                              LocallyLinearEmbedding)
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from sklearn.random_projection import (GaussianRandomProjection,
                                       SparseRandomProjection)
from sklearn.neighbors import (KNeighborsClassifier,
                               NeighborhoodComponentsAnalysis)                               
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import make_scorer, accuracy_score
from sklearn.model_selection import GridSearchCV

# %%
from xgboost import XGBClassifier
import umap as umap
from sklearn.manifold import TSNE
from sklearn.cluster import DBSCAN
#from numpy import random, where
from sklearn.metrics import accuracy_score, log_loss
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, BaggingClassifier, ExtraTreesClassifier 

from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE, ADASYN
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.over_sampling import SMOTENC
from imblearn.over_sampling import SMOTEN
from imblearn.under_sampling import RandomUnderSampler
from imblearn.under_sampling import ClusterCentroids
from imblearn.under_sampling import NearMiss
from imblearn.combine import SMOTEENN
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.under_sampling import RepeatedEditedNearestNeighbours
from imblearn.under_sampling import AllKNN
from imblearn.under_sampling import CondensedNearestNeighbour
from imblearn.under_sampling import OneSidedSelection
from imblearn.under_sampling import NeighbourhoodCleaningRule
from imblearn.under_sampling import InstanceHardnessThreshold
import random

# %%
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from sklearn.model_selection import ShuffleSplit
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_validate
from sklearn.metrics import recall_score
from sklearn.metrics import make_scorer
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedShuffleSplit

# %%
### Factor Analysis to figure out interactive latent variables
from sklearn.decomposition import FactorAnalysis
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
from factor_analyzer import FactorAnalyzer
from factor_analyzer.factor_analyzer import calculate_kmo
import os

# %% [markdown]
# # List involved resampling techniques

# %%
#### Random over-sampling
ros = RandomOverSampler(random_state=0)

#### SMOTE
smote = SMOTE()

### ADASYM
adasym = ADASYN()

borderline = BorderlineSMOTE()

sampler = SMOTEN(random_state=0)

### Combine
smote_enn = SMOTEENN(random_state=0)

smote_tomek = SMOTETomek(random_state=0)

### Under sampling
cc = ClusterCentroids(random_state=0)

rus = RandomUnderSampler(random_state=0)

rus1 = RandomUnderSampler(random_state=0,replacement=True)

nm1 = NearMiss(version=1)

enn = EditedNearestNeighbours()

enn1 = EditedNearestNeighbours(kind_sel="all")

enn2 = EditedNearestNeighbours(kind_sel="mode")

renn = RepeatedEditedNearestNeighbours()

allknn = AllKNN()

cnn = CondensedNearestNeighbour(random_state=0)

oss = OneSidedSelection(random_state=0)

ncr = NeighbourhoodCleaningRule()

iht = InstanceHardnessThreshold(random_state=0,
                                estimator=LogisticRegression(
                                    solver='lbfgs', multi_class='auto'))

# %% [markdown]
# # List classifiers

# %%
### Define selected models
# Use a nearest neighbor classifier to evaluate the methods
knn = KNeighborsClassifier()

# Logistic Regression
logreg_clf = LogisticRegression(multi_class='multinomial',solver="lbfgs")

# SVC Model
svc_clf = SVC() 

# LinearSVC Model
linsvc_clf = LinearSVC()

# Random Forest Model
rf_clf = RandomForestClassifier()

# GaussianNB Model
gnb_clf = GaussianNB()

# DecisionTree Model
dt_clf = DecisionTreeClassifier()

# XGBoost Model
xg_clf = XGBClassifier(objective="binary:logistic", n_estimators=10, seed=123)

Nsvc_clf = NuSVC(probability=True)

AdaBoost_clf = AdaBoostClassifier()

gradientB_clf = GradientBoostingClassifier()

linearD_clf = LinearDiscriminantAnalysis()

quadraticDA_clf = QuadraticDiscriminantAnalysis()

baggingC_clf = BaggingClassifier() 

extraTree_clf = ExtraTreesClassifier()

# %%
from sklearn.ensemble import VotingClassifier

# %% [markdown]
# # Read needed tables

# %%
allGame_Content_New_Combine_Data = pd.read_csv('allGameCombinedFeatureswithInterFactors.csv')

# %%
list(allGame_Content_New_Combine_Data.columns)
# Out:
# ['FirstLayer_task_speed_factor_1',
#  'FirstLayer_task_speed_factor_2',
#  'FirstLayer_task_speed_factor_3',
#  'FirstLayer_task_speed_factor_4',
#  'FirstLayer_task_speed_factor_5',
#  'FirstLayer_task_speed_factor_6',
#  'FirstLayer_task_speed_factor_7',
#  'FirstLayer_task_speed_factor_8',
#  'FirstLayer_task_speed_factor_9',
#  'FirstLayer_task_speed_factor_10',
#  'FirstLayer_task_speed_factor_11',
#  'FirstLayer_task_speed_factor_12',
#  'FirstLayer_task_speed_factor_13',
#  'FirstLayer_task_speed_factor_14',
#  'FirstLayer_task_speed_factor_15',
#  'FirstLayer_task_speed_factor_16',
#  'FirstLayer_task_speed_factor_17',
#  'FirstLayer_task_speed_factor_18',
#  'FirstLayer_task_speed_factor_19',
#  'FirstLayer_task_share_factor_1',
#  'FirstLayer_task_share_factor_2',
#  'FirstLayer_task_share_factor_3',
#  'FirstLayer_task_share_factor_4',
#  'FirstLayer_task_share_factor_5',
#  'FirstLayer_task_share_factor_6',
#  'FirstLayer_task_share_factor_7',
# ...

# %%
# Machine learning systems work with integers, we need to encode these
# string characters into ints

encoder = LabelEncoder()

# Now apply the transformation to all the columns:
for col in allGame_Content_New_Combine_Data.columns:
    allGame_Content_New_Combine_Data[col] = encoder.fit_transform(allGame_Content_New_Combine_Data[col])

y_label = allGame_Content_New_Combine_Data['POSTCONTENTSCORE']
X_features = allGame_Content_New_Combine_Data.drop(['playerName','POSTCONTENTSCORE'],axis=1)

# %%
y_label
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 458    0
# 459    0
# 460    1
# 461    0
# 462    0
# Name: POSTCONTENTSCORE, Length: 463, dtype: int32

# %%
X_features
# Out:
#      FirstLayer_task_speed_factor_1  FirstLayer_task_speed_factor_2  \
# 0                               217                              33
# 1                                63                             131
# 2                               317                             403
# 3                               197                             263
# 4                               145                              35
# ..                              ...                             ...
# 458                             186                              41
# 459                             362                             408
# 460                             420                             294
# 461                             377                             363
# 462                             381                             304
#
#      FirstLayer_task_speed_factor_3  FirstLayer_task_speed_factor_4  \
# 0                               354                             178
# ...

# %%
# Standardized the features
X_features_stdPre = StandardScaler().fit_transform(X_features)

# Feature selection
model = ExtraTreesClassifier()
random.seed(0)
model.fit(X_features_stdPre, y_label)
print(model.feature_importances_)
# Calculate the importance rate for feature selection
feat_importances = pd.Series(model.feature_importances_, index=X_features.columns)
# Out:
# [0.0014712  0.00230825 0.00167586 0.00273536 0.00172265 0.00173314
#  0.00369771 0.00228834 0.00149864 0.00342723 0.00140049 0.00179658
#  0.00295781 0.0040709  0.0025909  0.00225445 0.00582094 0.00296289
#  0.00255127 0.00219878 0.00343858 0.0028716  0.00379815 0.00194648
#  0.00253127 0.00232388 0.00229028 0.0021847  0.00311268 0.00228962
#  0.00245705 0.00214247 0.0023866  0.00307422 0.00197054 0.00180651
#  0.00180151 0.00345898 0.00276182 0.00268961 0.00148494 0.00205037
#  0.00269126 0.00169719 0.0016547  0.00461955 0.00208294 0.00284246
#  0.00324496 0.00268202 0.00290085 0.00162321 0.00183974 0.00175203
#  0.0041916  0.0028175  0.00944084 0.00188684 0.00252704 0.0013293
#  0.0028541  0.         0.00364704 0.00305491 0.00223953 0.0021
#  0.00208842 0.00246347 0.00268944 0.00198988 0.00240121 0.0017338
#  0.00363658 0.00216385 0.00293628 0.00220997 0.00178335 0.00175035
#  0.00300885 0.00218492 0.00151763 0.00157253 0.00255432 0.00280438
# ...

# %%
# Involve needed resampling method
resampling_method = {
    'RandomOver': ros,
    'Smote': smote,
    'adasym': adasym,
    'borderline': borderline,
    'SmoteN': sampler,
    'SmoteENN': smote_enn,
    'SmoteTomek': smote_tomek,
    'clusterCen': cc,
    'RandomUnder': rus,
    'RandomUnderReSam': rus1,
    'NearMiss': nm1,
    'NearestNeighbor': enn,
    'NearestNeighborAll': enn1,
    'NearestNeighborMode': enn2,
    'RepeatedNearNeighbor': renn,
    'allKNN': allknn,
    'CondensedNearNeighbor': cnn,
    'OnesidedSelection': oss,
    'NeighborCleaningRule': ncr,
    'InstanceHardness': iht
}

# %%
# Involve machine learning algorithms for the ensemble
model_fit_algorithm = {
    'SVC': svc_clf,
    'LinearSVC': linsvc_clf,
    'RFM': rf_clf,
    'GaussianNB': gnb_clf,
    'DTM': dt_clf,
    'XGBoost': xg_clf,
    'LogiReg': logreg_clf,
    'KNN': knn,
    'Nsvc': Nsvc_clf,
    'decisionTree': dt_clf,
    'AdaBoost': AdaBoost_clf,
    'gradientB': gradientB_clf,
    'linearD': linearD_clf,
    'quadraticDA': quadraticDA_clf,
    'baggingC': baggingC_clf,
    'extraTree': extraTree_clf,
    'gradientBoosting': gradientB_clf
}

# %%
ensemble_model = VotingClassifier(estimators=list(model_fit_algorithm.items()), voting='hard')

# %%
if not os.path.exists('allGameContentModelTrainingResults.csv'):
    outcome = pd.DataFrame(columns=['Feature Number', 'Iteration Number', 'Resampling Name', 
                                    'Test Accuracy', 'Macro Precision', 'Macro Recall', 'Macro F1', 
                                    'High Precision', 'High Recall', 'High F1', 
                                    'Low Precision', 'Low Recall', 'Low F1'])
    outcome.to_csv('allGameContentModelTrainingResults.csv', index=False)

# %%
# Metrics lists
featureNumber = []
iterationNumber = []
resampleMethod = []
modelName = []
testAccuracy = []
macroPrecision = []
macroRecall = []
macroF1 = []
highPrecision = []
highRecall = []
highF1 = []
lowPrecision = []
lowRecall = []
lowF1 = []

# Start the model training
for x in range(2, 376):
    LargestVar = pd.DataFrame(feat_importances.nlargest(x))
    cols = LargestVar.index
    X_features_1 = X_features[cols]

    # Prepare the dataset and parameters
    X_features_std = StandardScaler().fit_transform(X_features_1)
    # Parameters
    dim = len(X_features_std[0])
    n_classes = len(np.unique(y_label))
    
    for z in range(1, 16):
        random_state = z
        # Split into train/test
        X_train, X_test, y_train, y_test = train_test_split(X_features_std, y_label, test_size=0.2, stratify=y_label, random_state=random_state)

        
        try:
            for i, (Rname, method) in enumerate(resampling_method.items()):
                X_resample, Y_resample = method.fit_resample(X_train, y_train)
                # Fit the ensemble model
                ensemble_model.fit(X_resample, Y_resample)
                pred = ensemble_model.predict(X_test)
                class_report = classification_report(y_test, pred, target_names=['High', 'Low'], output_dict=True)
                
                # Extract metrics
                macro_precision = class_report['macro avg']['precision']
                macro_recall = class_report['macro avg']['recall']
                macro_f1 = class_report['macro avg']['f1-score']
                High_precision = class_report['High']['precision']
                High_recall = class_report['High']['recall']
                High_f1 = class_report['High']['f1-score']
                Low_precision = class_report['Low']['precision']
                Low_recall = class_report['Low']['recall']
                Low_f1 = class_report['Low']['f1-score']

                model_acc = accuracy_score(y_test, pred)
                print(model_acc)

                # Append metrics to lists
                featureNumber.append(x)
                iterationNumber.append(z)
                resampleMethod.append(Rname)
                testAccuracy.append(model_acc)
                macroPrecision.append(macro_precision)
                macroRecall.append(macro_recall)
                macroF1.append(macro_f1)
                highPrecision.append(High_precision)
                highRecall.append(High_recall)
                highF1.append(High_f1)
                lowPrecision.append(Low_precision)
                lowRecall.append(Low_recall)
                lowF1.append(Low_f1)
                outcome = pd.DataFrame([[x, z, Rname, model_acc, macro_precision, macro_recall, macro_f1, 
                                        High_precision, High_recall, High_f1, Low_precision, Low_recall, Low_f1]],
                                        columns=['Feature Number', 'Iteration Number', 'Resampling Name', 
                                                 'Test Accuracy', 'Macro Precision', 'Macro Recall', 'Macro F1', 
                                                 'High Precision', 'High Recall', 'High F1', 
                                                 'Low Precision', 'Low Recall', 'Low F1'])
                
                # Append results to CSV file
                with open('allGameContentModelTrainingResults.csv', 'a') as f:
                    outcome.to_csv(f, header=False, index=False)

        except Exception:
            print("An error occurred, moving on to the next iteration")
# Out:
# 0.6236559139784946
# 0.6236559139784946
# 0.6021505376344086
# 0.6236559139784946
# 0.6236559139784946
# 0.6021505376344086
# 0.6236559139784946
# 0.6021505376344086
# 0.6236559139784946
# 0.6021505376344086
# An error occurred, moving on to the next iteration
# 0.7096774193548387
# 0.7096774193548387
# 0.6774193548387096
# 0.6774193548387096
# 0.7096774193548387
# 0.6774193548387096
# 0.7096774193548387
# 0.5483870967741935
# 0.6774193548387096
# 0.7096774193548387
# An error occurred, moving on to the next iteration
# 0.6559139784946236
# 0.6559139784946236
# 0.6559139784946236
# 0.6559139784946236
# 0.6559139784946236
# An error occurred, moving on to the next iteration
# 0.7526881720430108
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.7526881720430108
# An error occurred, moving on to the next iteration
# 0.6451612903225806
# 0.6451612903225806
# 0.6451612903225806
# 0.6451612903225806
# 0.6451612903225806
# An error occurred, moving on to the next iteration
# ...

# %% [markdown]
# # Filter the best results

# %%
Overall_content_model_training_results = pd.read_csv("allGameContentModelTrainingResults.csv")

# %%
avg_accuracy = Overall_content_model_training_results.groupby(['Feature Number', 'Resampling Name'])['Test Accuracy'].mean().reset_index()

highest_avg_accuracy = avg_accuracy.loc[avg_accuracy['Test Accuracy'].idxmax()]

print("Combination with the highest average Test Accuracy:")
print(highest_avg_accuracy)
# Out:
# Combination with the highest average Test Accuracy:
# Feature Number             45
# Resampling Name    SmoteTomek
# Test Accuracy          0.8614
# Name: 871, dtype: object

# %%
best_results = pd.DataFrame(Overall_content_model_training_results[(Overall_content_model_training_results['Feature Number'] == 45) & (Overall_content_model_training_results['Resampling Name'] == 'SmoteTomek')])
best_results
# Out:
#        Feature Number  Iteration Number Resampling Name  Test Accuracy  \
# 721                45                12      SmoteTomek          0.865
# 2956               45                14      SmoteTomek          0.834
# 2963               45                15      SmoteTomek          0.879
# 4809               45                 9      SmoteTomek          0.852
# 4813               45                10      SmoteTomek          0.890
# 12565              45                 3      SmoteTomek          0.861
# 12571              45                 6      SmoteTomek          0.843
# 12574              45                 7      SmoteTomek          0.870
# 12585              45                13      SmoteTomek          0.858
# 15799              45                 4      SmoteTomek          0.876
# 15813              45                 8      SmoteTomek          0.849
# 22852              45                 2      SmoteTomek          0.881
# ...
